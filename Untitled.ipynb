# %%
import json
import pandas as pd

# %%
df = pd.read_json('data.json', orient='index')

# %%
print(df.to_string())
# Out:
#                                                                                                                                                                                                                                                                                                                                          0                                                                                                                                                                                                                                                                                                                                      1                                                                                                                                                                                                                                                                                                                               2                     
# ...

# %%
pd.json_normalize(df, max_level=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11228\1598397677.py in <module>
# ----> 1 pd.json_normalize(df, max_level=0)
#
# c:\users\mari\appdata\local\programs\python\python37\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     436
#     437     if record_path is None:
# --> 438         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     439             # naive normalization, this is idempotent for flat records
#     440             # and potentially will inflate the data considerably for
#
# c:\users\mari\appdata\local\programs\python\python37\lib\site-packages\pandas\io\json\_normalize.py in <genexpr>(.0)
#     436
#     437     if record_path is None:
# ...
